# %%
import numpy as np
import csv
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 10)

# %%
with open('deepQ_agent_rewards_moretrain.csv', 'r') as f:
    reader = csv.reader(f)
    raw_coins = list(reader)
coins = np.array([item for sublist in raw_coins for item in sublist]).astype(np.float)
print(np.shape(coins))
# Out:
# (298,)

# %%
rounds = np.arange(len(coins))

# %%
plt.plot(rounds,coins,linestyle='None',marker='x')

# %%
plt.plot(rounds[:1000],coins[:1000],linestyle='None',marker='x')

# %%
N = 9
y, z = np.zeros(N), np.zeros(N)
x = np.arange(N)*100
for i in range(N):
    start = i*100
    stop = (i+1)*100
    sample = coins[start:stop]
    y[i] = np.mean(sample)
    z[i] = np.sum(sample[sample==9])/9
plt.plot(x,y)
plt.ylim(0,8)
# Out:
# /home/jan/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/jan/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# (0, 8)

# %%
plt.plot(x,z)

# %%
print(z)
# Out:
# [ 54. 189. 207. 171. 189. 252. 225. 207. 198.]
