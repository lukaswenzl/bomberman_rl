# %%
from __future__ import print_function, division
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
convergence = np.loadtxt("step1_qmatrix_Feb10.out")

# %%
size = convergence.shape[0]

plt.figure(figsize=(3,3))
plt.plot(range(size), convergence)

plt.ylabel(r"measure of convergence")
plt.xlabel(r"number of episodes")
#plt.title(r"Title here (remove for papers)")
#plt.xlim(0, 2*np.pi)
#plt.ylim(-1.1, 1.1)
#plt.legend(loc="lower left")
plt.tight_layout()
plt.savefig("step1_convergence.pdf")

# %%
[q.for q in qmatrices

# %%
a = np.array([2,34,3])

# %%
np.array([a.tolist(),a])
# Out:
# array([[ 2, 34,  3],
#        [ 2, 34,  3]])
